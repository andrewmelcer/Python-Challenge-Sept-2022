# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#input data
data = {'Gender': ['Male', 'Male', 'Male', 'Female', 'Female','Female'],
        'HeightCM': [171, 161, 180, 166, 150, 167],
        'WeightKG':[96, 85, 77, 62, 70, 82]
        }

# %%
#create new data frame with pandas
df=pd.DataFrame(data)

# %%
#check data frame
df
# Out:
#    Gender  HeightCM  WeightKG
# 0    Male       171        96
# 1    Male       161        85
# 2    Male       180        77
# 3  Female       166        62
# 4  Female       150        70
# 5  Female       167        82

# %%
#change centimeters to meters in order to calculate BMI
df['HeightM'] = df['HeightCM']/100

# %%
#create height squared variable to calculate BMI
heightsq = df[('HeightM')]**2

# %%
#check variable functionality 
heightsq
# Out:
# 0    2.9241
# 1    2.5921
# 2    3.2400
# 3    2.7556
# 4    2.2500
# 5    2.7889
# Name: HeightM, dtype: float64

# %%
#calculate BMI
BMI = df['WeightKG']/heightsq

# %%
#check variable functionality 
BMI
# Out:
# 0    32.830615
# 1    32.791945
# 2    23.765432
# 3    22.499637
# 4    31.111111
# 5    29.402273
# dtype: float64

# %%
#cut decimal places to 1
BMI = BMI.round(1)

# %%
BMI
# Out:
# 0    32.8
# 1    32.8
# 2    23.8
# 3    22.5
# 4    31.1
# 5    29.4
# dtype: float64

# %%
#add BMI column to data frame
df['BMI'] = BMI

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI
# 0    Male       171        96     1.71  32.8
# 1    Male       161        85     1.61  32.8
# 2    Male       180        77     1.80  23.8
# 3  Female       166        62     1.66  22.5
# 4  Female       150        70     1.50  31.1
# 5  Female       167        82     1.67  29.4

# %%
#add BMI category with range 'Underweight', 'Normal Weight', 'Overweight','Moderately Obese', 'Severely Obese', 'Very Severely Obese'
df['BMI Category'] = pd.cut(df['BMI'], bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 100], labels=['Underweight', 'Normal Weight', 'Overweight','Moderately Obese', 'Severely Obese', 'Very Severely Obese'])

# %%
# Check if data frame is updated
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category
# 0    Male       171        96     1.71  32.8  Moderately Obese
# 1    Male       161        85     1.61  32.8  Moderately Obese
# 2    Male       180        77     1.80  23.8     Normal Weight
# 3  Female       166        62     1.66  22.5     Normal Weight
# 4  Female       150        70     1.50  31.1  Moderately Obese
# 5  Female       167        82     1.67  29.4        Overweight

# %%
#add Health Risk category with range 'Malnutrition Risk', 'Low Risk', 'Enhanced Risk', 'Medium Risk', 'High Risk', 'Very High Risk'
df['Health Risk'] = pd.cut(df['BMI'], bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 100], labels=['Malnutrition Risk', 'Low Risk', 'Enhanced Risk', 'Medium Risk', 'High Risk', 'Very High Risk'])

# %%
# Check if data frame is updated
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category    Health Risk
# 0    Male       171        96     1.71  32.8  Moderately Obese    Medium Risk
# 1    Male       161        85     1.61  32.8  Moderately Obese    Medium Risk
# 2    Male       180        77     1.80  23.8     Normal Weight       Low Risk
# 3  Female       166        62     1.66  22.5     Normal Weight       Low Risk
# 4  Female       150        70     1.50  31.1  Moderately Obese    Medium Risk
# 5  Female       167        82     1.67  29.4        Overweight  Enhanced Risk

# %%
#add new row to data frame with new data to test functionality
#first lets check someone that has a BMI of less than 18.4
df2 = {'Gender':'Female', 'HeightCM':200, 'WeightKG':40}

# %%
#append df2 to df
df = df.append(df2, ignore_index=True)

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category    Health Risk
# 0    Male       171        96     1.71  32.8  Moderately Obese    Medium Risk
# 1    Male       161        85     1.61  32.8  Moderately Obese    Medium Risk
# 2    Male       180        77     1.80  23.8     Normal Weight       Low Risk
# 3  Female       166        62     1.66  22.5     Normal Weight       Low Risk
# 4  Female       150        70     1.50  31.1  Moderately Obese    Medium Risk
# 5  Female       167        82     1.67  29.4        Overweight  Enhanced Risk
# 6  Female       200        40      NaN   NaN               NaN            NaN

# %%
#change centimeters to meters in order to calculate BMI
df['HeightM'] = df['HeightCM']/100

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category    Health Risk
# 0    Male       171        96     1.71  32.8  Moderately Obese    Medium Risk
# 1    Male       161        85     1.61  32.8  Moderately Obese    Medium Risk
# 2    Male       180        77     1.80  23.8     Normal Weight       Low Risk
# 3  Female       166        62     1.66  22.5     Normal Weight       Low Risk
# 4  Female       150        70     1.50  31.1  Moderately Obese    Medium Risk
# 5  Female       167        82     1.67  29.4        Overweight  Enhanced Risk
# 6  Female       200        40     2.00   NaN               NaN            NaN

# %%
#create height squared variable to calculate BMI
heightsq = df[('HeightM')]**2

# %%
BMI = df['WeightKG']/heightsq

# %%
BMI = BMI.round(1)

# %%
BMI
# Out:
# 0    32.8
# 1    32.8
# 2    23.8
# 3    22.5
# 4    31.1
# 5    29.4
# 6    10.0
# dtype: float64

# %%
#create for loop to calculate BMI for all rows
for i in range(len(df)):
    df['BMI'] = df['WeightKG']/heightsq

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category    Health Risk
# 0    Male       171        96     1.71  32.8  Moderately Obese    Medium Risk
# 1    Male       161        85     1.61  32.8  Moderately Obese    Medium Risk
# 2    Male       180        77     1.80  23.8     Normal Weight       Low Risk
# 3  Female       166        62     1.66  22.5     Normal Weight       Low Risk
# 4  Female       150        70     1.50  31.1  Moderately Obese    Medium Risk
# 5  Female       167        82     1.67  29.4        Overweight  Enhanced Risk
# 6  Female       200        40     2.00  10.0               NaN            NaN

# %%
#create for loop to calculate BMI category for all rows
for i in range(len(df)):
    df['BMI Category'] = pd.cut(df['BMI'], bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 100], labels=['Underweight', 'Normal Weight', 'Overweight','Moderately Obese', 'Severely Obese', 'Very Severely Obese'])

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category    Health Risk
# 0    Male       171        96     1.71  32.8  Moderately Obese    Medium Risk
# 1    Male       161        85     1.61  32.8  Moderately Obese    Medium Risk
# 2    Male       180        77     1.80  23.8     Normal Weight       Low Risk
# 3  Female       166        62     1.66  22.5     Normal Weight       Low Risk
# 4  Female       150        70     1.50  31.1  Moderately Obese    Medium Risk
# 5  Female       167        82     1.67  29.4        Overweight  Enhanced Risk
# 6  Female       200        40     2.00  10.0       Underweight            NaN

# %%
#create for loop to calculate Health Risk category for all rows
for i in range(len(df)):
    df['Health Risk'] = pd.cut(df['BMI'], bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 100], labels=['Malnutrition Risk', 'Low Risk', 'Enhanced Risk', 'Medium Risk', 'High Risk', 'Very High Risk'])

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category  \
# 0    Male       171        96     1.71  32.8  Moderately Obese
# 1    Male       161        85     1.61  32.8  Moderately Obese
# 2    Male       180        77     1.80  23.8     Normal Weight
# 3  Female       166        62     1.66  22.5     Normal Weight
# 4  Female       150        70     1.50  31.1  Moderately Obese
# 5  Female       167        82     1.67  29.4        Overweight
# 6  Female       200        40     2.00  10.0       Underweight
#
#          Health Risk
# 0        Medium Risk
# 1        Medium Risk
# 2           Low Risk
# 3           Low Risk
# 4        Medium Risk
# 5      Enhanced Risk
# 6  Malnutrition Risk

# %%
#add another new row to data frame with new data to test functionality
#now lets check for someone with a BMI of over 40
df3 = {'Gender':'Male', 'HeightCM':150, 'WeightKG':100}

# %%
#append df3 to df
df = df.append(df3, ignore_index=True)

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category  \
# 0    Male       171        96     1.71  32.8  Moderately Obese
# 1    Male       161        85     1.61  32.8  Moderately Obese
# 2    Male       180        77     1.80  23.8     Normal Weight
# 3  Female       166        62     1.66  22.5     Normal Weight
# 4  Female       150        70     1.50  31.1  Moderately Obese
# 5  Female       167        82     1.67  29.4        Overweight
# 6  Female       200        40     2.00  10.0       Underweight
# 7    Male       150       100      NaN   NaN               NaN
#
#          Health Risk
# 0        Medium Risk
# 1        Medium Risk
# 2           Low Risk
# 3           Low Risk
# 4        Medium Risk
# 5      Enhanced Risk
# 6  Malnutrition Risk
# 7                NaN

# %%
#change centimeters to meters in order to calculate BMI
df['HeightM'] = df['HeightCM']/100

# %%
heightsq = df[('HeightM')]**2

# %%
BMI = df['WeightKG']/heightsq

# %%
BMI
# Out:
# 0    32.830615
# 1    32.791945
# 2    23.765432
# 3    22.499637
# 4    31.111111
# 5    29.402273
# 6    10.000000
# 7    44.444444
# dtype: float64

# %%
#test for loop to calculate BMI for all rows
for i in range(len(df)):
    df['BMI'] = df['WeightKG']/heightsq

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM        BMI      BMI Category  \
# 0    Male       171        96     1.71  32.830615  Moderately Obese
# 1    Male       161        85     1.61  32.791945  Moderately Obese
# 2    Male       180        77     1.80  23.765432     Normal Weight
# 3  Female       166        62     1.66  22.499637     Normal Weight
# 4  Female       150        70     1.50  31.111111  Moderately Obese
# 5  Female       167        82     1.67  29.402273        Overweight
# 6  Female       200        40     2.00  10.000000       Underweight
# 7    Male       150       100     1.50  44.444444               NaN
#
#          Health Risk
# 0        Medium Risk
# 1        Medium Risk
# 2           Low Risk
# 3           Low Risk
# 4        Medium Risk
# 5      Enhanced Risk
# 6  Malnutrition Risk
# 7                NaN

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI      BMI Category  \
# 0    Male       171        96     1.71  32.8  Moderately Obese
# 1    Male       161        85     1.61  32.8  Moderately Obese
# 2    Male       180        77     1.80  23.8     Normal Weight
# 3  Female       166        62     1.66  22.5     Normal Weight
# 4  Female       150        70     1.50  31.1  Moderately Obese
# 5  Female       167        82     1.67  29.4        Overweight
# 6  Female       200        40     2.00  10.0       Underweight
# 7    Male       150       100     1.50  44.4               NaN
#
#          Health Risk
# 0        Medium Risk
# 1        Medium Risk
# 2           Low Risk
# 3           Low Risk
# 4        Medium Risk
# 5      Enhanced Risk
# 6  Malnutrition Risk
# 7                NaN

# %%
#test for loop to calculate BMI category for all rows
for i in range(len(df)):
    df['BMI Category'] = pd.cut(df['BMI'], bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 100], labels=['Underweight', 'Normal Weight', 'Overweight','Moderately Obese', 'Severely Obese', 'Very Severely Obese'])

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI         BMI Category  \
# 0    Male       171        96     1.71  32.8     Moderately Obese
# 1    Male       161        85     1.61  32.8     Moderately Obese
# 2    Male       180        77     1.80  23.8        Normal Weight
# 3  Female       166        62     1.66  22.5        Normal Weight
# 4  Female       150        70     1.50  31.1     Moderately Obese
# 5  Female       167        82     1.67  29.4           Overweight
# 6  Female       200        40     2.00  10.0          Underweight
# 7    Male       150       100     1.50  44.4  Very Severely Obese
#
#          Health Risk
# 0        Medium Risk
# 1        Medium Risk
# 2           Low Risk
# 3           Low Risk
# 4        Medium Risk
# 5      Enhanced Risk
# 6  Malnutrition Risk
# 7                NaN

# %%
#test for loop to calculate Health Risk category for all rows
for i in range(len(df)):
    df['Health Risk'] = pd.cut(df['BMI'], bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 100], labels=['Malnutrition Risk', 'Low Risk', 'Enhanced Risk', 'Medium Risk', 'High Risk', 'Very High Risk'])

# %%
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI         BMI Category  \
# 0    Male       171        96     1.71  32.8     Moderately Obese
# 1    Male       161        85     1.61  32.8     Moderately Obese
# 2    Male       180        77     1.80  23.8        Normal Weight
# 3  Female       166        62     1.66  22.5        Normal Weight
# 4  Female       150        70     1.50  31.1     Moderately Obese
# 5  Female       167        82     1.67  29.4           Overweight
# 6  Female       200        40     2.00  10.0          Underweight
# 7    Male       150       100     1.50  44.4  Very Severely Obese
#
#          Health Risk
# 0        Medium Risk
# 1        Medium Risk
# 2           Low Risk
# 3           Low Risk
# 4        Medium Risk
# 5      Enhanced Risk
# 6  Malnutrition Risk
# 7     Very High Risk

# %%
#create function to calculate BMI, BMI Category, and Health Risk
def BMI_Calc(df):
    df['HeightM'] = df['HeightCM']/100
    df['HeightSquared'] = df['HeightM']**2
    df['BMI'] = (df['WeightKG']/df['HeightSquared']).round(1)
    df['BMI Category'] = pd.cut(df['BMI'], bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 100], labels=['Underweight', 'Normal Weight', 'Overweight','Moderately Obese', 'Severely Obese', 'Very Severely Obese'])
    df['Health Risk'] = pd.cut(df['BMI'], bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 100], labels=['Malnutrition Risk', 'Low Risk', 'Enhanced Risk', 'Medium Risk', 'High Risk', 'Very High Risk'])
    return df

# %%
BMI_Calc(df)
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI         BMI Category  \
# 0    Male       171        96     1.71  32.8     Moderately Obese
# 1    Male       161        85     1.61  32.8     Moderately Obese
# 2    Male       180        77     1.80  23.8        Normal Weight
# 3  Female       166        62     1.66  22.5        Normal Weight
# 4  Female       150        70     1.50  31.1     Moderately Obese
# 5  Female       167        82     1.67  29.4           Overweight
# 6  Female       200        40     2.00  10.0          Underweight
# 7    Male       150       100     1.50  44.4  Very Severely Obese
#
#          Health Risk  HeightSquared
# 0        Medium Risk         2.9241
# 1        Medium Risk         2.5921
# 2           Low Risk         3.2400
# 3           Low Risk         2.7556
# 4        Medium Risk         2.2500
# 5      Enhanced Risk         2.7889
# 6  Malnutrition Risk         4.0000
# 7     Very High Risk         2.2500

# %%
#test function with new data
df4 = {'Gender':'Female', 'HeightCM':170, 'WeightKG':70}

# %%
df.append(df4, ignore_index=True)
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI         BMI Category  \
# 0    Male       171        96     1.71  32.8     Moderately Obese
# 1    Male       161        85     1.61  32.8     Moderately Obese
# 2    Male       180        77     1.80  23.8        Normal Weight
# 3  Female       166        62     1.66  22.5        Normal Weight
# 4  Female       150        70     1.50  31.1     Moderately Obese
# 5  Female       167        82     1.67  29.4           Overweight
# 6  Female       200        40     2.00  10.0          Underweight
# 7    Male       150       100     1.50  44.4  Very Severely Obese
# 8  Female       170        70      NaN   NaN                  NaN
#
#          Health Risk  HeightSquared
# 0        Medium Risk         2.9241
# 1        Medium Risk         2.5921
# 2           Low Risk         3.2400
# 3           Low Risk         2.7556
# 4        Medium Risk         2.2500
# 5      Enhanced Risk         2.7889
# 6  Malnutrition Risk         4.0000
# 7     Very High Risk         2.2500
# 8                NaN            NaN

# %%
#update data frame
df=df.append(df4, ignore_index=True)

# %%
BMI_Calc(df)
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI         BMI Category  \
# 0    Male       171        96     1.71  32.8     Moderately Obese
# 1    Male       161        85     1.61  32.8     Moderately Obese
# 2    Male       180        77     1.80  23.8        Normal Weight
# 3  Female       166        62     1.66  22.5        Normal Weight
# 4  Female       150        70     1.50  31.1     Moderately Obese
# 5  Female       167        82     1.67  29.4           Overweight
# 6  Female       200        40     2.00  10.0          Underweight
# 7    Male       150       100     1.50  44.4  Very Severely Obese
#
#          Health Risk  HeightSquared
# 0        Medium Risk         2.9241
# 1        Medium Risk         2.5921
# 2           Low Risk         3.2400
# 3           Low Risk         2.7556
# 4        Medium Risk         2.2500
# 5      Enhanced Risk         2.7889
# 6  Malnutrition Risk         4.0000
# 7     Very High Risk         2.2500

# %%
# BMI_Calc function will return the BMI rounded to one decimal point
# as well as BMI Category and Health Risk
df
# Out:
#    Gender  HeightCM  WeightKG  HeightM   BMI         BMI Category  \
# 0    Male       171        96     1.71  32.8     Moderately Obese
# 1    Male       161        85     1.61  32.8     Moderately Obese
# 2    Male       180        77     1.80  23.8        Normal Weight
# 3  Female       166        62     1.66  22.5        Normal Weight
# 4  Female       150        70     1.50  31.1     Moderately Obese
# 5  Female       167        82     1.67  29.4           Overweight
# 6  Female       200        40     2.00  10.0          Underweight
# 7    Male       150       100     1.50  44.4  Very Severely Obese
#
#          Health Risk  HeightSquared
# 0        Medium Risk         2.9241
# 1        Medium Risk         2.5921
# 2           Low Risk         3.2400
# 3           Low Risk         2.7556
# 4        Medium Risk         2.2500
# 5      Enhanced Risk         2.7889
# 6  Malnutrition Risk         4.0000
# 7     Very High Risk         2.2500
